# %%
# %matplotlib notebook
#if use Jupyter Notebook, run this command before calling matplotlib in notebook.

# %%
from matplotlib import pyplot as plt

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rect=plt.Rectangle((0.2,0.75),0.4,0.15,color='k',alpha=0.3)
circ=plt.Circle((0.7,0.2),0.15,color='b',alpha=0.3)
pgon=plt.Polygon([[0.15, 0.15],[0.35,0.4],[0.2,0.6]],
                color='g', alpha=0.5)
#here Circle initially render in figure will look like not so round, but oval,
#due to y axis is not same scale as x axis at first.
#If drag the figure to absolute square, the circle will not look like oval.

# %%
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
plt.savefig('3patch.png', dpi=400, bbox_inches='tight')
