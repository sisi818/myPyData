# %%
# %matplotlib notebook
#if use Jupyter Notebook, run this command before calling matplotlib in notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax=fig.add_subplot(1,1,1)

# %%
ax.plot(np.random.randn(1000).cumsum())

# %%
ticks=ax.set_xticks([0,250,500,750,1000])

# %%
labels=ax.set_xticklabels(['one','two','three','four','five'],
                         rotation=30, fontsize='small')

# %%
ax.set_title('My first matplotlib plot')
# Out:
# Text(0.5, 1, 'My first matplotlib plot')

# %%
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 10.763891973024519, 'Stages')

# %%
props={
    'title':'My first matplotlib plot example',
    'xlabel':'Test Stages'
}

# %%
ax.set(**props)
# Out:
# [Text(0.5, 10.763891973024519, 'Test Stages'),
#  Text(0.5, 1, 'My first matplotlib plot example')]
