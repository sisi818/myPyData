# %%
# %matplotlib notebook
#if use Jupyter Notebook, run this command before calling matplotlib in notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fig, axes=plt.subplots(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data=pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))

# %%
data.plot.bar(ax=axes[0], color='k', alpha=0.7)

# %%
data.plot.barh(ax=axes[1], color='k', alpha=0.5)

# %%
#data.value_counts().plot.bar()

# %%
df=pd.DataFrame(np.random.rand(6,4),
               index=['one','two','three','four','five','six'],
               columns=pd.Index(['A','B','C','D'], name='Genus'))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.947618  0.014611  0.244863  0.651889
# two    0.487089  0.453959  0.016642  0.452192
# three  0.923392  0.429133  0.981113  0.036707
# four   0.835333  0.370679  0.468270  0.766492
# five   0.466892  0.293568  0.241428  0.775895
# six    0.232670  0.446645  0.227920  0.341073

# %%
df.plot.bar()
#Note: don't be df.plot().bar()....will same with df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">
