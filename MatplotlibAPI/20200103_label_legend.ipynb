# %%
# %matplotlib notebook
#if use Jupyter Notebook, run this command before calling matplotlib in notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax=fig.add_subplot(1,1,1)

# %%
ax.plot(np.random.randn(1000).cumsum(),'ko', label='one')

# %%
ax.plot(np.random.randn(1000).cumsum(),'r--', label='two')

# %%
ax.plot(np.random.randn(1000).cumsum(),'b.', label='three')

# %%
ax.legend(loc='best')

# %%
ax.text(200,35,'Hello My first Plot!',
       family='monospace', fontsize=11)
# Out:
# Text(200, 35, 'Hello My first Plot!')
