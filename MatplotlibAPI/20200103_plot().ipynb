# %%
# %matplotlib notebook
#if use Jupyter Notebook, run this command before calling matplotlib in notebook.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
s=pd.Series(np.random.randn(10).cumsum(), index=np.arange(0,100,10))

# %%
s
# Out:
# 0     0.039050
# 10    0.503919
# 20    2.125601
# 30    2.861416
# 40    3.793972
# 50    4.048120
# 60    3.986915
# 70    1.346312
# 80    1.663806
# 90   -0.469663
# dtype: float64

# %%
s.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df=pd.DataFrame(np.random.randn(10,4).cumsum(0),
               columns=['A','B','C','D'],
               index=np.arange(0,100,10))

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df
# Out:
#            A         B         C         D
# 0   0.411374  1.069627 -0.325203  1.453210
# 10  1.605994 -0.099947 -0.385325  2.326812
# 20  3.188235 -1.009757 -1.176242  3.073901
# 30  2.883821  1.092336 -3.704739  2.122972
# 40  3.706547  0.686007 -4.191044  3.054265
# 50  4.517825  0.429398 -3.089182  3.038675
# 60  5.028425  1.608190 -3.067425  4.428553
# 70  5.882218  2.942207 -3.621425  3.460209
# 80  5.472302  2.039220 -2.195371  2.205118
# 90  5.434499  1.600313 -3.610508  2.893127
