# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.plot(np.random.randn(50).cumsum())

# %%
plt.plot(np.random.randn(500).cumsum())

# %%
a=[1,2,3]

# %%
b=a

# %%
a.append(5)

# %%
b
# Out:
# [1, 2, 3, 5]

# %%
type(a)
# Out:
# list

# %%
type(b)
# Out:
# list

# %%
b='foo'

# %%
type(b)
# Out:
# str

# %%
a=5.5;b=2

# %%
print('a is {0}, b is {1}'.format(type(a), type(b)))
# Out:
# a is <class 'float'>, b is <class 'int'>

# %%
a/b
# Out:
# 2.75

# %%
c= a/b

# %%
c
# Out:
# 2.75

# %%
type(a);type(b);type(c)
# Out:
# float

# %%
type(b)
# Out:
# int

# %%
data=[1,3,5,7]

# %%
isinstance(data, list)
# Out:
# True

# %%
str1='foo'

# %%
str1.translate?

# %%
ival=111111

# %%
ival**5
# Out:
# 16935003133160595268336551

# %%
ival2=ival**5

# %%
ival2
# Out:
# 16935003133160595268336551

# %%
ival3=ival2**5

# %%
ival3
# Out:
# 1392920745627194349827157324742129595849227789836349192877295811595128336307077969484832919896342789341010058529312037833207751

# %%
5//2
# Out:
# 2

# %%
s=r'this\has\no\special\characters'

# %%
s
# Out:
# 'this\\has\\no\\special\\characters'

# %%
s2=s.replace('\','$')
# Out:
#   File "<ipython-input-10-3eba4bfeb3a5>", line 1
#     s2=s.replace('\','$')
#                       ^
# SyntaxError: invalid syntax

# %%
s2=s.replace('\\','\$')

# %%
s2
# Out:
# 'this\\$has\\$no\\$special\\$characters'

# %%
s='this\has\no\special\characters'

# %%
s3=s.replace('\\','\$')

# %%
s3
# Out:
# 'this\\$has\no\\$special\\$characters'

# %%
s3=s.replace('\',"\$")
# Out:
#   File "<ipython-input-16-ad29c6dd02cc>", line 1
#     s3=s.replace('\',"\$")
#                           ^
# SyntaxError: EOL while scanning string literal

# %%
s3=s.replace("\","\$")
# Out:
#   File "<ipython-input-17-67427d0a908d>", line 1
#     s3=s.replace("\","\$")
#                           ^
# SyntaxError: unexpected character after line continuation character

# %%
s3=s.replace('\\','$')

# %%
s3
# Out:
# 'this$has\no$special$characters'

# %%
s='this\has\no\special\characters'

# %%
s3=s.replace('\\','$')

# %%
s3
# Out:
# 'this$has\no$special$characters'

# %%
s2=r'this\has\no\special\characters'

# %%
s3=s.replace('\\','$')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-59ad768c7386> in <module>
# ----> 1 s3=s.replace('\\','$')
#
# NameError: name 's' is not defined

# %%
s3=s2.replace('\\','$')

# %%
s3
# Out:
# 'this$has$no$special$characters'
